# %% [markdown]
# # 10-714 Final Project
#
# In this homework, you will be implementing a neural network library in the needle framework. Reminder: __you must save a copy in drive__.

# %%
# Code to set up the assignment
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/
# !mkdir -p 10714
# %cd /content/drive/MyDrive/10714
# !git clone https://github.com/dlsys10714/hw2.git
# %cd /content/drive/MyDrive/10714/hw2

# !pip3 install --upgrade --no-deps git+https://github.com/dlsys10714/mugrade.git

# %% [markdown]
# ### Setting some variables

# %%
MY_API_KEY = "nx0Fe2aqigIavqhNBrgD"
HW2_NAME = "hw2"

# %% [markdown]
# ## Question 0
#
# This homework builds off of Homework 1.
#
# **First, in your Homework 2 directory, copy the files `python/needle/autograd.py`, `python/needle/ops/ops_mathematic.py` from your Homework 1.**
#
# ***NOTE***: The default data type for the tensor is `float32`. If you want to change the data type, you can do so by setting the `dtype` parameter in the `Tensor` constructor. For example, `Tensor([1, 2, 3], dtype='float64')` will create a tensor with `float64` data type.
# In this homework, **make sure any tensor you create has `float32` data type to avoid any issues with the autograder**.

# %%
# Download the PTB dataset

import urllib.request
import os

# !mkdir -p './data/ptb'
# Download Penn Treebank dataset
ptb_data = "https://raw.githubusercontent.com/wojzaremba/lstm/master/data/ptb."
for f in ['train.txt', 'test.txt', 'valid.txt']:
    if not os.path.exists(os.path.join('./data/ptb', f)):
        urllib.request.urlretrieve(ptb_data + f, os.path.join('./data/ptb', f))

# %%
import sys
sys.path.append('./python')
sys.path.append('./apps')

# %%
# !python -m pytest -v tests/test_sparse_ops.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.18, pytest-8.4.1, pluggy-1.6.0 -- /home/ktsim/miniconda3/envs/dl-systems/bin/python
# cachedir: .pytest_cache
# rootdir: /home/ktsim/Projects/Sparse-Attention
# collected 20 items
#
# tests/hw3/test_sparse_ops.py::test_sparse_add[numpy] PASSED              [  5%]
# tests/hw3/test_sparse_ops.py::test_sparse_add[csr] PASSED                [ 10%]
# tests/hw3/test_sparse_ops.py::test_sparse_multiply[numpy] PASSED         [ 15%]
# tests/hw3/test_sparse_ops.py::test_sparse_multiply[csr] PASSED           [ 20%]
# tests/hw3/test_sparse_ops.py::test_sparse_mul_scalar[numpy] PASSED       [ 25%]
# tests/hw3/test_sparse_ops.py::test_sparse_mul_scalar[csr] PASSED         [ 30%]
# tests/hw3/test_sparse_ops.py::test_sparse_add_scalar[numpy] PASSED       [ 35%]
# tests/hw3/test_sparse_ops.py::test_sparse_add_scalar[csr] PASSED         [ 40%]
# tests/hw3/test_sparse_ops.py::test_sparse_matmul[numpy] PASSED           [ 45%]
# tests/hw3/test_sparse_ops.py::test_sparse_matmul[csr] PASSED             [ 50%]
# tests/hw3/test_sparse_ops.py::test_sparse_transpose[numpy] PASSED        [ 55%]
# tests/hw3/test_sparse_ops.py::test_sparse_transpose[csr] PASSED          [ 60%]
# tests/hw3/test_sparse_ops.py::test_sparse_relu[numpy] PASSED             [ 65%]
# tests/hw3/test_sparse_ops.py::test_sparse_relu[csr] PASSED               [ 70%]
# tests/hw3/test_sparse_ops.py::test_dense_sparse_roundtrip PASSED         [ 75%]
# tests/hw3/test_sparse_ops.py::test_sparse_multiply_sum_matches_dense PASSED [ 80%]
# tests/hw3/test_sparse_ops.py::test_sparse_matmul_backward PASSED         [ 85%]
# tests/hw3/test_sparse_ops.py::test_sparse_sum[numpy] PASSED              [ 90%]
# tests/hw3/test_sparse_ops.py::test_sparse_sum[csr] PASSED                [ 95%]
# tests/hw3/test_sparse_ops.py::test_sparse_sum_backward PASSED            [100%]
#
# ============================== 20 passed in 0.08s ==============================

# %%
# !python -m pytest -v tests/test_sparse_attention.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.18, pytest-8.4.1, pluggy-1.6.0 -- /home/ktsim/miniconda3/envs/dl-systems/bin/python
# cachedir: .pytest_cache
# rootdir: /home/ktsim/Projects/Sparse-Attention
# collected 4 items
#
# tests/hw3/test_sparse_attention.py::test_local_window_attention_matches_dense PASSED [ 25%]
# tests/hw3/test_sparse_attention.py::test_global_token_attention_matches_dense PASSED [ 50%]
# tests/hw3/test_sparse_attention.py::test_random_attention_matches_dense PASSED [ 75%]
# tests/hw3/test_sparse_attention.py::test_sparse_attention_respects_causal_mask PASSED [100%]
#
# ============================== 4 passed in 0.07s ===============================

# %%
# !python -m pytest -v tests/test_transformer.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.18, pytest-8.4.1, pluggy-1.6.0 -- /home/ktsim/miniconda3/envs/dl-systems/bin/python
# cachedir: .pytest_cache
# rootdir: /home/ktsim/Projects/Sparse-Attention
# collected 112 items
#
# tests/test_transformer.py::test_attention_activation[cpu-0.0-False-64-31-5-4] PASSED [  0%]
# tests/test_transformer.py::test_attention_activation[cpu-0.0-False-64-31-5-8] PASSED [  1%]
# tests/test_transformer.py::test_attention_activation[cpu-0.0-True-64-31-5-4] PASSED [  2%]
# tests/test_transformer.py::test_attention_activation[cpu-0.0-True-64-31-5-8] PASSED [  3%]
# tests/test_transformer.py::test_attention_activation[cpu-0.1-False-64-31-5-4] PASSED [  4%]
# tests/test_transformer.py::test_attention_activation[cpu-0.1-False-64-31-5-8] PASSED [  5%]
# tests/test_transformer.py::test_attention_activation[cpu-0.1-True-64-31-5-4] PASSED [  6%]
# tests/test_transformer.py::test_attention_activation[cpu-0.1-True-64-31-5-8] PASSED [  7%]
# tests/test_transformer.py::test_attention_activation[cuda-0.0-False-64-31-5-4] PASSED [  8%]
# tests/test_transformer.py::test_attention_activation[cuda-0.0-False-64-31-5-8] PASSED [  8%]
# tests/test_transformer.py::test_attention_activation[cuda-0.0-True-64-31-5-4] PASSED [  9%]
# tests/test_transformer.py::test_attention_activation[cuda-0.0-True-64-31-5-8] PASSED [ 10%]
# tests/test_transformer.py::test_attention_activation[cuda-0.1-False-64-31-5-4] PASSED [ 11%]
# tests/test_transformer.py::test_attention_activation[cuda-0.1-False-64-31-5-8] PASSED [ 12%]
# tests/test_transformer.py::test_attention_activation[cuda-0.1-True-64-31-5-4] PASSED [ 13%]
# tests/test_transformer.py::test_attention_activation[cuda-0.1-True-64-31-5-8] PASSED [ 14%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-5-4] FAILED [ 15%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-5-8] FAILED [ 16%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-11-4] FAILED [ 16%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-11-8] FAILED [ 17%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-5-4] FAILED [ 18%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-5-8] FAILED [ 19%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-11-4] FAILED [ 20%]
# tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-11-8] FAILED [ 21%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-5-4] FAILED [ 22%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-5-8] FAILED [ 23%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-11-4] FAILED [ 24%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-11-8] FAILED [ 25%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-5-4] FAILED [ 25%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-5-8] FAILED [ 26%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-11-4] FAILED [ 27%]
# tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-11-8] FAILED [ 28%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-5-4] FAILED [ 29%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-5-8] FAILED [ 30%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-11-4] FAILED [ 31%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-11-8] FAILED [ 32%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-5-4] FAILED [ 33%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-5-8] FAILED [ 33%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-11-4] FAILED [ 34%]
# tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-11-8] FAILED [ 35%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-5-4] FAILED [ 36%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-5-8] FAILED [ 37%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-11-4] FAILED [ 38%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-11-8] FAILED [ 39%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-5-4] FAILED [ 40%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-5-8] FAILED [ 41%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-11-4] FAILED [ 41%]
# tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-11-8] FAILED [ 42%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-5-2] FAILED [ 43%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-5-4] FAILED [ 44%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-11-2] FAILED [ 45%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-11-4] FAILED [ 46%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-5-2] FAILED [ 47%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-5-4] FAILED [ 48%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-11-2] FAILED [ 49%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-11-4] FAILED [ 50%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-5-2] FAILED [ 50%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-5-4] FAILED [ 51%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-11-2] FAILED [ 52%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-11-4] FAILED [ 53%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-5-2] FAILED [ 54%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-5-4] FAILED [ 55%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-11-2] FAILED [ 56%]
# tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-11-4] FAILED [ 57%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-5-2] FAILED [ 58%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-5-4] FAILED [ 58%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-11-2] FAILED [ 59%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-11-4] FAILED [ 60%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-5-2] FAILED [ 61%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-5-4] FAILED [ 62%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-11-2] FAILED [ 63%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-11-4] FAILED [ 64%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-5-2] FAILED [ 65%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-5-4] FAILED [ 66%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-11-2] FAILED [ 66%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-11-4] FAILED [ 67%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-5-2] FAILED [ 68%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-5-4] FAILED [ 69%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-11-2] FAILED [ 70%]
# tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-11-4] FAILED [ 71%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-2-64-27-5-8] FAILED [ 72%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-2-64-27-11-8] FAILED [ 73%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-4-64-27-5-8] FAILED [ 74%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-4-64-27-11-8] FAILED [ 75%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-2-64-27-5-8] FAILED [ 75%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-2-64-27-11-8] FAILED [ 76%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-4-64-27-5-8] FAILED [ 77%]
# tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-4-64-27-11-8] FAILED [ 78%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-2-64-27-5-8] FAILED [ 79%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-2-64-27-11-8] FAILED [ 80%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-4-64-27-5-8] FAILED [ 81%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-4-64-27-11-8] FAILED [ 82%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-2-64-27-5-8] FAILED [ 83%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-2-64-27-11-8] FAILED [ 83%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-4-64-27-5-8] FAILED [ 84%]
# tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-4-64-27-11-8] FAILED [ 85%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-2-64-27-5-8] FAILED [ 86%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-2-64-27-11-8] FAILED [ 87%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-4-64-27-5-8] FAILED [ 88%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-4-64-27-11-8] FAILED [ 89%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-2-64-27-5-8] FAILED [ 90%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-2-64-27-11-8] FAILED [ 91%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-4-64-27-5-8] FAILED [ 91%]
# tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-4-64-27-11-8] FAILED [ 92%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-2-64-27-5-8] FAILED [ 93%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-2-64-27-11-8] FAILED [ 94%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-4-64-27-5-8] FAILED [ 95%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-4-64-27-11-8] FAILED [ 96%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-2-64-27-5-8] FAILED [ 97%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-2-64-27-11-8] FAILED [ 98%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-4-64-27-5-8] FAILED [ 99%]
# tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-4-64-27-11-8] FAILED [100%]
#
# =================================== FAILURES ===================================
# _______________ test_attention_layer[cpu-0.0-False-32-8-27-5-4] ________________
#
# batch_size = 4, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.0-False-32-8-27-5-8] ________________
#
# batch_size = 8, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.0-False-32-8-27-11-4] _______________
#
# batch_size = 4, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.0-False-32-8-27-11-8] _______________
#
# batch_size = 8, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# ________________ test_attention_layer[cpu-0.0-True-32-8-27-5-4] ________________
#
# batch_size = 4, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# ________________ test_attention_layer[cpu-0.0-True-32-8-27-5-8] ________________
#
# batch_size = 8, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.0-True-32-8-27-11-4] ________________
#
# batch_size = 4, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.0-True-32-8-27-11-8] ________________
#
# batch_size = 8, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.0, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.1-False-32-8-27-5-4] ________________
#
# batch_size = 4, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.1-False-32-8-27-5-8] ________________
#
# batch_size = 8, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.1-False-32-8-27-11-4] _______________
#
# batch_size = 4, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.1-False-32-8-27-11-8] _______________
#
# batch_size = 8, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# ________________ test_attention_layer[cpu-0.1-True-32-8-27-5-4] ________________
#
# batch_size = 4, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# ________________ test_attention_layer[cpu-0.1-True-32-8-27-5-8] ________________
#
# batch_size = 8, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.1-True-32-8-27-11-4] ________________
#
# batch_size = 4, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cpu-0.1-True-32-8-27-11-8] ________________
#
# batch_size = 8, seq_len = 11, input_dim = 27, num_head = 8, dim_head = 32
# causal = True, dropout = 0.1, device = cpu()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cpu(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cuda-0.0-False-32-8-27-5-4] _______________
#
# batch_size = 4, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.0, device = cuda()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cuda(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# _______________ test_attention_layer[cuda-0.0-False-32-8-27-5-8] _______________
#
# batch_size = 8, seq_len = 5, input_dim = 27, num_head = 8, dim_head = 32
# causal = False, dropout = 0.0, device = cuda()
#
#     @pytest.mark.parametrize("batch_size", [4, 8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_attention_layer(batch_size, seq_len, input_dim, num_head, dim_head, causal, dropout, device):
#
#         np.random.seed(19943)
#
#         q = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         k = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         v = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#
# >       layer = AttentionLayer(
#             input_dim, num_head, dim_head,
#             dropout=dropout, causal=causal, device=device)
#
# tests/test_transformer.py:89:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
# ...
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# ____________ test_transformer_model[cuda-0.1-True-32-8-4-64-27-5-8] ____________
#
# batch_size = 8, seq_len = 5, input_dim = 27, hidden_size = 64, num_layers = 4
# num_head = 8, dim_head = 32, causal = True, dropout = 0.1, device = cuda()
#
#     @pytest.mark.parametrize("batch_size", [8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("hidden_size", [64])
#     @pytest.mark.parametrize("num_layers", [2, 4])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_transformer_model(
#             batch_size, seq_len, input_dim,
#             hidden_size, num_layers,
#             num_head, dim_head,
#             causal, dropout, device):
#
#         np.random.seed(19943)
#
#         x = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         ndl_x = ndl.Tensor(x, device=device)
#
# >       model = Transformer(
#             input_dim, hidden_size, num_layers,
#             num_head=num_head,
#             dim_head=dim_head,
#             dropout=dropout,
#             causal=causal,
#             device=device,
#             batch_first=True,
#         )
#
# tests/test_transformer.py:182:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:479: in __init__
#     self.transformer_layers = Sequential(*[
# python/needle/nn/nn_transformer_sparse.py:480: in <listcomp>
#     TransformerLayer(
# python/needle/nn/nn_transformer_sparse.py:393: in __init__
#     self.self_attn = AttentionLayer(
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cuda(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# ___________ test_transformer_model[cuda-0.1-True-32-8-4-64-27-11-8] ____________
#
# batch_size = 8, seq_len = 11, input_dim = 27, hidden_size = 64, num_layers = 4
# num_head = 8, dim_head = 32, causal = True, dropout = 0.1, device = cuda()
#
#     @pytest.mark.parametrize("batch_size", [8])
#     @pytest.mark.parametrize("seq_len", [5, 11])
#     @pytest.mark.parametrize("input_dim", [27])
#     @pytest.mark.parametrize("hidden_size", [64])
#     @pytest.mark.parametrize("num_layers", [2, 4])
#     @pytest.mark.parametrize("num_head", [8])
#     @pytest.mark.parametrize("dim_head", [32])
#     @pytest.mark.parametrize("causal", [False, True])
#     @pytest.mark.parametrize("dropout", [0.0, 0.1])
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_transformer_model(
#             batch_size, seq_len, input_dim,
#             hidden_size, num_layers,
#             num_head, dim_head,
#             causal, dropout, device):
#
#         np.random.seed(19943)
#
#         x = np.random.randn(
#             batch_size, seq_len, input_dim
#         ).astype(np.float32)
#         ndl_x = ndl.Tensor(x, device=device)
#
# >       model = Transformer(
#             input_dim, hidden_size, num_layers,
#             num_head=num_head,
#             dim_head=dim_head,
#             dropout=dropout,
#             causal=causal,
#             device=device,
#             batch_first=True,
#         )
#
# tests/test_transformer.py:182:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_transformer_sparse.py:479: in __init__
#     self.transformer_layers = Sequential(*[
# python/needle/nn/nn_transformer_sparse.py:480: in <listcomp>
#     TransformerLayer(
# python/needle/nn/nn_transformer_sparse.py:393: in __init__
#     self.self_attn = AttentionLayer(
# python/needle/nn/nn_transformer_sparse.py:305: in __init__
#     self.q_projection = Linear(
# python/needle/nn/nn_basic.py:117: in __init__
#     self.weight = Parameter(init.kaiming_uniform(in_features, out_features, device=device, dtype=dtype, requires_grad=True))
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# fan_in = 27, fan_out = 256, nonlinearity = 'relu'
# kwargs = {'device': cuda(), 'dtype': 'float32', 'requires_grad': True}
#
#     def kaiming_uniform(fan_in, fan_out, nonlinearity="relu", **kwargs):
#         assert nonlinearity == "relu", "Only relu supported currently"
#         ### BEGIN YOUR SOLUTION
# >       raise NotImplementedError()
# E       NotImplementedError
#
# python/needle/init/init_initializers.py:20: NotImplementedError
# =========================== short test summary info ============================
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-False-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.0-True-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-False-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cpu-0.1-True-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-False-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.0-True-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-False-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_attention_layer[cuda-0.1-True-32-8-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-False-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.0-True-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-False-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cpu-0.1-True-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-False-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.0-True-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-False-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-5-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-5-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-11-2] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_layer[cuda-0.1-True-64-32-8-27-11-4] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-False-32-8-4-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.0-True-32-8-4-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-False-32-8-4-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cpu-0.1-True-32-8-4-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-False-32-8-4-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.0-True-32-8-4-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-False-32-8-4-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-2-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-2-64-27-11-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-4-64-27-5-8] - NotImplementedError
# FAILED tests/test_transformer.py::test_transformer_model[cuda-0.1-True-32-8-4-64-27-11-8] - NotImplementedError
# ======================== 96 failed, 16 passed in 2.60s =========================
